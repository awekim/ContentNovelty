# %% [markdown]
# # **Create a dataset**
# - pub_affauth_eu.csv
# - pub_affinst_eu.csv

# %% [markdown]
# # **1. Include external collab papers**
# - External collab papers are included in the calculation of the centroid
# - 1_df_incl_external_collab.csv

# %%
import pandas as pd
affauth = pd.read_csv('pub_affauth_eu.csv')

# drop author_id_te and addr_num 
affauth = affauth.drop(columns=['author_id_te', 'addr_num'])
affauth = affauth.drop_duplicates()
affauth
# Out:
#                pubid  pubyear EU_NUTS_ID
# 0             2010.0     1998      ES415
# 4             2012.0     1998      NL327
# 6             2013.0     1998      ES111
# 11            2015.0     1998      UKJ36
# 15            2019.0     1998      PL331
# ...              ...      ...        ...
# 58188985  46608438.0     2021      FR101
# 58188986  46608438.0     2021      PT170
# 58188987  46608438.0     2021      NL423
# 58188989  46608438.0     2021      NL326
# 58188992  46608438.0     2021      FR431
#
# [17571115 rows x 3 columns]

# %%
# count the number of unique author_id_te 
affauth['author_id_te'].nunique()
# Out:
# 11062495

# %%
# Group by 'author_id_te' and count the number of unique EU_NUTS_IDs
author_region_counts = affauth.groupby('author_id_te')['EU_NUTS_ID'].nunique()

# Filter for authors associated with more than one region
authors_with_multiple_regions = author_region_counts[author_region_counts > 1]

# Get the count of such authors
num_authors_with_multiple_regions = len(authors_with_multiple_regions)

print(f"Number of authors associated with multiple EU_NUTS_IDs: {num_authors_with_multiple_regions}")
# Out:
# Number of authors associated with multiple EU_NUTS_IDs: 2363001

# %%
2363001 / 11062495
# Out:
# 0.21360470671399173

# %%
publication = pd.read_csv('pub_pub_eu.csv')
# drop pubyear 
publication = publication.drop(columns=['pubyear'])
publication
# Out:
#                pubid                                          itemtitle  \
# 0             2010.0  Pharmacology of JB-9315, a new selective hista...
# 1             2012.0  Focal cerebral ischemia in the mouse: Hypother...
# 2             2013.0  Pyridazine derivatives XIV. Study of the vasor...
# 3             2015.0  Structural requirements and ionic mechanism of...
# 4             2019.0  Activity of lysosomal system in mouse liver af...
# ...              ...                                                ...
# 10032662  46608401.0  A population-level strain genotyping method to...
# 10032663  46608410.0  A disorder clinically resembling cystic fibros...
# 10032664  46608423.0  Melanoma secretion of transforming growth fact...
# 10032665  46608429.0  Karlodinium veneficum: Growth optimization, me...
# 10032666  46608438.0  Inflammation of the Sacroiliac Joints and Spin...
#
#                                                    abstract
# 0         \r\n<p>1. The histamine H-2 receptor antagonis...
# 1         \r\n<p>1. We have investigated the ability of ...
# 2         \r\n<p>1. For several years we have been worki...
# 3         \r\n<p>1. The structural and ionic requirement...
# 4         \r\n<p>1. The effect of taxol on selected lyso...
# ...                                                     ...
# 10032662  \r\n<p>A hallmark of chronic bacterial infecti...
# 10032663  \r\n<p>Purpose We sought to describe a disorde...
# 10032664  \r\n<p>Background For patients with early Amer...
# 10032665  \r\n<p>Aim of this study The major aim of this...
# 10032666  \r\n<p>Objective To test the impact of inflamm...
#
# [10032667 rows x 3 columns]

# %%
subjects = pd.read_csv('pub_subject_eu.csv')

# drop pubyear 
subjects = subjects.drop(columns=['pubyear'])
subjects
# Out:
#                pubid     ascatype                               subject
# 0             2010.0     extended               Pharmacology & Pharmacy
# 1             2010.0  traditional               Pharmacology & Pharmacy
# 2             2012.0     extended               Pharmacology & Pharmacy
# 3             2012.0  traditional               Pharmacology & Pharmacy
# 4             2013.0     extended               Pharmacology & Pharmacy
# ...              ...          ...                                   ...
# 32680572  46608429.0     extended                          Microbiology
# 32680573  46608429.0  traditional  Biotechnology & Applied Microbiology
# 32680574  46608429.0  traditional                          Microbiology
# 32680575  46608438.0     extended                          Rheumatology
# 32680576  46608438.0  traditional                          Rheumatology
#
# [32680577 rows x 3 columns]

# %%
# check the number of unique subjects where ascatype = extended 
subjects_extended = subjects[subjects['ascatype'] == 'extended']
num_unique_subjects_extended = subjects_extended['subject'].nunique()
print(f"Number of unique subjects with ascatype 'extended': {num_unique_subjects_extended}")
# Out:
# Number of unique subjects with ascatype 'extended': 152

# %%
# check the number of unique subjects where ascatype = traditional 
subjects_traditional = subjects[subjects['ascatype'] == 'traditional']
num_unique_subjects_traditional = subjects_traditional['subject'].nunique()
print(f"Number of unique subjects with ascatype 'traditional': {num_unique_subjects_traditional}")
# Out:
# Number of unique subjects with ascatype 'traditional': 256

# %%
# keep rows where ascatype is extended 
subjects = subjects[subjects['ascatype'] == 'extended']
subjects = subjects.drop(columns=['ascatype'])
subjects = subjects.drop_duplicates() 
subjects
# Out:
#                pubid                               subject
# 0             2010.0               Pharmacology & Pharmacy
# 2             2012.0               Pharmacology & Pharmacy
# 4             2013.0               Pharmacology & Pharmacy
# 6             2015.0               Pharmacology & Pharmacy
# 8             2019.0               Pharmacology & Pharmacy
# ...              ...                                   ...
# 32680567  46608410.0                   Genetics & Heredity
# 32680569  46608423.0                           Dermatology
# 32680571  46608429.0  Biotechnology & Applied Microbiology
# 32680572  46608429.0                          Microbiology
# 32680575  46608438.0                          Rheumatology
#
# [15780480 rows x 2 columns]

# %%
df = pd.merge(affauth, publication, on='pubid', how='left')
df
# Out:
#                pubid  pubyear EU_NUTS_ID  \
# 0             2010.0     1998      ES415
# 1             2012.0     1998      NL327
# 2             2013.0     1998      ES111
# 3             2015.0     1998      UKJ36
# 4             2019.0     1998      PL331
# ...              ...      ...        ...
# 17571110  46608438.0     2021      FR101
# 17571111  46608438.0     2021      PT170
# 17571112  46608438.0     2021      NL423
# 17571113  46608438.0     2021      NL326
# 17571114  46608438.0     2021      FR431
#
#                                                   itemtitle  \
# 0         Pharmacology of JB-9315, a new selective hista...
# 1         Focal cerebral ischemia in the mouse: Hypother...
# 2         Pyridazine derivatives XIV. Study of the vasor...
# 3         Structural requirements and ionic mechanism of...
# 4         Activity of lysosomal system in mouse liver af...
# ...                                                     ...
# 17571110  Inflammation of the Sacroiliac Joints and Spin...
# 17571111  Inflammation of the Sacroiliac Joints and Spin...
# 17571112  Inflammation of the Sacroiliac Joints and Spin...
# 17571113  Inflammation of the Sacroiliac Joints and Spin...
# 17571114  Inflammation of the Sacroiliac Joints and Spin...
#
#                                                    abstract
# 0         \r\n<p>1. The histamine H-2 receptor antagonis...
# 1         \r\n<p>1. We have investigated the ability of ...
# 2         \r\n<p>1. For several years we have been worki...
# 3         \r\n<p>1. The structural and ionic requirement...
# 4         \r\n<p>1. The effect of taxol on selected lyso...
# ...                                                     ...
# 17571110  \r\n<p>Objective To test the impact of inflamm...
# 17571111  \r\n<p>Objective To test the impact of inflamm...
# 17571112  \r\n<p>Objective To test the impact of inflamm...
# 17571113  \r\n<p>Objective To test the impact of inflamm...
# 17571114  \r\n<p>Objective To test the impact of inflamm...
#
# [17571115 rows x 5 columns]

# %%
# group by pubyear and EU_NUTS_ID and count the number of unique pubid
df.groupby(['pubyear', 'EU_NUTS_ID'])['pubid'].nunique().sort_index()
# Out:
# pubyear  EU_NUTS_ID
# 1998     AT111            1
#          AT112            7
#          AT113            3
#          AT121            7
#          AT122           16
#                        ...
# 2021     UKN01         2798
#          UKN02          384
#          UKN03           80
#          UKN04          561
#          UKN05          101
# Name: pubid, Length: 32351, dtype: int64

# %%
# check the number of unique pubid for each pubyear
df.groupby('pubyear')['pubid'].nunique().sort_index()
# Out:
# pubyear
# 1998    271457
# 1999    277423
# 2000    281163
# 2001    283183
# 2002    284335
# 2003    291954
# 2004    301536
# 2005    312048
# 2006    328168
# 2007    349233
# 2008    364407
# 2009    372445
# 2010    386176
# 2011    453469
# 2012    472901
# 2013    496512
# 2014    500520
# 2015    514727
# 2016    530416
# 2017    540196
# 2018    551802
# 2019    569131
# 2020    621721
# 2021    677744
# Name: pubid, dtype: int64

# %%
# create 'period' column 
def assign_period(pubyear):
    if 1998 <= pubyear <= 2001:
        return 1
    elif 2002 <= pubyear <= 2005:
        return 2
    elif 2006 <= pubyear <= 2009:
        return 3
    elif 2010 <= pubyear <= 2013:
        return 4
    elif 2014 <= pubyear <= 2017:
        return 5
    elif 2018 <= pubyear <= 2021:
        return 6
    else:
        return None

df['period'] = df['pubyear'].apply(assign_period)
df.head()
# Out:
#     pubid  pubyear EU_NUTS_ID  \
# 0  2010.0     1998      ES415
# 1  2012.0     1998      NL327
# 2  2013.0     1998      ES111
# 3  2015.0     1998      UKJ36
# 4  2019.0     1998      PL331
#
#                                            itemtitle  \
# 0  Pharmacology of JB-9315, a new selective hista...
# 1  Focal cerebral ischemia in the mouse: Hypother...
# 2  Pyridazine derivatives XIV. Study of the vasor...
# 3  Structural requirements and ionic mechanism of...
# 4  Activity of lysosomal system in mouse liver af...
#
#                                             abstract  period
# 0  \r\n<p>1. The histamine H-2 receptor antagonis...       1
# 1  \r\n<p>1. We have investigated the ability of ...       1
# 2  \r\n<p>1. For several years we have been worki...       1
# 3  \r\n<p>1. The structural and ionic requirement...       1
# 4  \r\n<p>1. The effect of taxol on selected lyso...       1

# %%
df = pd.merge(df, subjects, on='pubid', how='left')
df
# Out:
#                pubid  pubyear EU_NUTS_ID  \
# 0             2010.0     1998      ES415
# 1             2012.0     1998      NL327
# 2             2013.0     1998      ES111
# 3             2015.0     1998      UKJ36
# 4             2019.0     1998      PL331
# ...              ...      ...        ...
# 27357673  46608438.0     2021      FR101
# 27357674  46608438.0     2021      PT170
# 27357675  46608438.0     2021      NL423
# 27357676  46608438.0     2021      NL326
# 27357677  46608438.0     2021      FR431
#
#                                                   itemtitle  \
# 0         Pharmacology of JB-9315, a new selective hista...
# 1         Focal cerebral ischemia in the mouse: Hypother...
# 2         Pyridazine derivatives XIV. Study of the vasor...
# 3         Structural requirements and ionic mechanism of...
# 4         Activity of lysosomal system in mouse liver af...
# ...                                                     ...
# 27357673  Inflammation of the Sacroiliac Joints and Spin...
# 27357674  Inflammation of the Sacroiliac Joints and Spin...
# 27357675  Inflammation of the Sacroiliac Joints and Spin...
# 27357676  Inflammation of the Sacroiliac Joints and Spin...
# 27357677  Inflammation of the Sacroiliac Joints and Spin...
#
#                                                    abstract  period  \
# 0         \r\n<p>1. The histamine H-2 receptor antagonis...       1
# 1         \r\n<p>1. We have investigated the ability of ...       1
# 2         \r\n<p>1. For several years we have been worki...       1
# 3         \r\n<p>1. The structural and ionic requirement...       1
# 4         \r\n<p>1. The effect of taxol on selected lyso...       1
# ...                                                     ...     ...
# 27357673  \r\n<p>Objective To test the impact of inflamm...       6
# 27357674  \r\n<p>Objective To test the impact of inflamm...       6
# 27357675  \r\n<p>Objective To test the impact of inflamm...       6
# 27357676  \r\n<p>Objective To test the impact of inflamm...       6
# 27357677  \r\n<p>Objective To test the impact of inflamm...       6
#
#                           subject
# 0         Pharmacology & Pharmacy
# 1         Pharmacology & Pharmacy
# 2         Pharmacology & Pharmacy
# 3         Pharmacology & Pharmacy
# 4         Pharmacology & Pharmacy
# ...                           ...
# 27357673             Rheumatology
# 27357674             Rheumatology
# 27357675             Rheumatology
# 27357676             Rheumatology
# 27357677             Rheumatology
#
# [27357678 rows x 7 columns]

# %%
# remove '\r\n<p>' from the abstracts 
df['abstract'] = df['abstract'].str.replace('\r\n<p>', '')
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 # remove '\r\n<p>' from the abstracts
# ----> 2 df['abstract'] = df['abstract'].str.replace('\r\n<p>', '')
#       3 df.head()
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:137, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     132     msg = (
#     133         f"Cannot use .str.{func_name} with values of "
#     134         f"inferred dtype '{self._inferred_dtype}'."
#     135     )
#     136     raise TypeError(msg)
# --> 137 return func(self, *args, **kwargs)
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:1567, in StringMethods.replace(self, pat, repl, n, case, flags, regex)
#    1564 if case is None:
#    1565     case = True
# -> 1567 result = self._data.array._str_replace(
#    1568     pat, repl, n=n, case=case, flags=flags, regex=regex
#    1569 )
#    1570 return self._wrap_result(result)
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\strings\object_array.py:179, in ObjectStringArrayMixin._str_replace(self, pat, repl, n, case, flags, regex)
#     176 else:
#     177     f = lambda x: x.replace(pat, repl, n)
# --> 179 return self._str_map(f, dtype=str)
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\strings\object_array.py:78, in ObjectStringArrayMixin._str_map(self, f, na_value, dtype, convert)
#      76 map_convert = convert and not np.all(mask)
#      77 try:
# ---> 78     result = lib.map_infer_mask(arr, f, mask.view(np.uint8), map_convert)
#      79 except (TypeError, AttributeError) as err:
#      80     # Reraise the exception if callable `f` got wrong number of args.
#      81     # The user may want to be warned by this, instead of getting NaN
#      82     p_err = (
#      83         r"((takes)|(missing)) (?(2)from \d+ to )?\d+ "
#      84         r"(?(3)required )positional arguments?"
#      85     )
#
# File lib.pyx:2895, in pandas._libs.lib.map_infer_mask()
#
# File lib.pyx:2932, in pandas._libs.lib._map_infer_mask()
#
# File c:\Users\user\anaconda3\Lib\site-packages\pandas\core\strings\object_array.py:177, in ObjectStringArrayMixin._str_replace.<locals>.<lambda>(x)
#     175     f = lambda x: pat.sub(repl=repl, string=x, count=n)
#     176 else:
# --> 177     f = lambda x: x.replace(pat, repl, n)
#     179 return self._str_map(f, dtype=str)
#
# KeyboardInterrupt:

# %%
# group by pubyear and EU_NUTS_ID and count the number of unique pubid
check = df.groupby(['period', 'EU_NUTS_ID', 'subject'])['pubid'].nunique().sort_index()
check
# Out:
# period  EU_NUTS_ID  subject
# 1       AT111       Biochemistry & Molecular Biology       1
#                     Cardiovascular System & Cardiology     1
#                     General & Internal Medicine            1
#                     Immunology                             1
#                     Surgery                                1
#                                                           ..
# 6       UKN05       Urban Studies                          1
#                     Urology & Nephrology                   1
#                     Veterinary Sciences                   18
#                     Virology                               2
#                     Water Resources                        1
# Name: pubid, Length: 581773, dtype: int64

# %%
check.describe()
# Out:
# count    581773.000000
# mean         47.010499
# std         178.798345
# min           1.000000
# 25%           2.000000
# 50%           6.000000
# 75%          27.000000
# max       10350.000000
# Name: pubid, dtype: float64

# %% [markdown]
# **1-1. 지역별, 기간별, 분야별 논문 수가 최소 10개 이상인 지역만 포함**

# %%
# Step 1: Count number of unique pubid per group
group_counts = df.groupby(['period', 'EU_NUTS_ID', 'subject'])['pubid'].nunique().reset_index(name='count')

# Step 2: Filter to only keep groups with count >= 10
valid_groups = group_counts[group_counts['count'] >= 10][['period', 'EU_NUTS_ID', 'subject']]

# Step 3: Merge with original dataframe to keep only valid rows
df_filtered = df.merge(valid_groups, on=['period', 'EU_NUTS_ID', 'subject'], how='inner')
df_filtered
# Out:
#                pubid  pubyear EU_NUTS_ID  \
# 0             2010.0     1998      ES415
# 1             2012.0     1998      NL327
# 2             2013.0     1998      ES111
# 3             2015.0     1998      UKJ36
# 4             3080.0     1998      NL230
# ...              ...      ...        ...
# 26299162  46608438.0     2021      FR101
# 26299163  46608438.0     2021      PT170
# 26299164  46608438.0     2021      NL423
# 26299165  46608438.0     2021      NL326
# 26299166  46608438.0     2021      FR431
#
#                                                   itemtitle  \
# 0         Pharmacology of JB-9315, a new selective hista...
# 1         Focal cerebral ischemia in the mouse: Hypother...
# 2         Pyridazine derivatives XIV. Study of the vasor...
# 3         Structural requirements and ionic mechanism of...
# 4         Comparison of DNA application methods to reduc...
# ...                                                     ...
# 26299162  Inflammation of the Sacroiliac Joints and Spin...
# 26299163  Inflammation of the Sacroiliac Joints and Spin...
# 26299164  Inflammation of the Sacroiliac Joints and Spin...
# 26299165  Inflammation of the Sacroiliac Joints and Spin...
# 26299166  Inflammation of the Sacroiliac Joints and Spin...
#
#                                                    abstract  period  \
# 0         1. The histamine H-2 receptor antagonistic act...       1
# 1         1. We have investigated the ability of several...       1
# 2         1. For several years we have been working on t...       1
# 3         1. The structural and ionic requirements for p...       1
# 4         We compared the protection afforded by three d...       1
# ...                                                     ...     ...
# 26299162  Objective To test the impact of inflammation o...       6
# 26299163  Objective To test the impact of inflammation o...       6
# 26299164  Objective To test the impact of inflammation o...       6
# 26299165  Objective To test the impact of inflammation o...       6
# 26299166  Objective To test the impact of inflammation o...       6
#
#                           subject
# 0         Pharmacology & Pharmacy
# 1         Pharmacology & Pharmacy
# 2         Pharmacology & Pharmacy
# 3         Pharmacology & Pharmacy
# 4                      Immunology
# ...                           ...
# 26299162             Rheumatology
# 26299163             Rheumatology
# 26299164             Rheumatology
# 26299165             Rheumatology
# 26299166             Rheumatology
#
# [26299167 rows x 7 columns]

# %%
# Optional: check result
print(f"Original rows: {len(df)}")
print(f"Filtered rows: {len(df_filtered)}")
# Out:
# Original rows: 27357678
# Filtered rows: 26299167

# %%
# group by pubyear and EU_NUTS_ID and count the number of unique pubid
check = df_filtered.groupby(['period', 'EU_NUTS_ID', 'subject'])['pubid'].nunique().sort_index()
check.describe()
# Out:
# count    242318.000000
# mean        108.531628
# std         265.063667
# min          10.000000
# 25%          18.000000
# 50%          36.000000
# 75%          93.000000
# max       10350.000000
# Name: pubid, dtype: float64

# %%
df_filtered.to_csv('1_df_incl_external_collab.csv', index=False)

# %% [markdown]
# # **2. Exclude external collab papers**
# - External collab papers are excluded in the calculation of the centroid
# - 1_df_excl_external_collab.csv

# %%
import pandas as pd
affauth = pd.read_csv('pub_affauth_eu.csv')

# drop author_id_te and addr_num 
affauth = affauth.drop(columns=['author_id_te', 'addr_num'])
affauth = affauth.drop_duplicates()
affauth
# Out:
#                pubid  pubyear EU_NUTS_ID
# 0             2010.0     1998      ES415
# 4             2012.0     1998      NL327
# 6             2013.0     1998      ES111
# 11            2015.0     1998      UKJ36
# 15            2019.0     1998      PL331
# ...              ...      ...        ...
# 58188985  46608438.0     2021      FR101
# 58188986  46608438.0     2021      PT170
# 58188987  46608438.0     2021      NL423
# 58188989  46608438.0     2021      NL326
# 58188992  46608438.0     2021      FR431
#
# [17571115 rows x 3 columns]

# %%
publication = pd.read_csv('pub_pub_eu.csv')
# drop pubyear 
publication = publication.drop(columns=['pubyear'])
publication
# Out:
#                pubid                                          itemtitle  \
# 0             2010.0  Pharmacology of JB-9315, a new selective hista...
# 1             2012.0  Focal cerebral ischemia in the mouse: Hypother...
# 2             2013.0  Pyridazine derivatives XIV. Study of the vasor...
# 3             2015.0  Structural requirements and ionic mechanism of...
# 4             2019.0  Activity of lysosomal system in mouse liver af...
# ...              ...                                                ...
# 10032662  46608401.0  A population-level strain genotyping method to...
# 10032663  46608410.0  A disorder clinically resembling cystic fibros...
# 10032664  46608423.0  Melanoma secretion of transforming growth fact...
# 10032665  46608429.0  Karlodinium veneficum: Growth optimization, me...
# 10032666  46608438.0  Inflammation of the Sacroiliac Joints and Spin...
#
#                                                    abstract
# 0         \r\n<p>1. The histamine H-2 receptor antagonis...
# 1         \r\n<p>1. We have investigated the ability of ...
# 2         \r\n<p>1. For several years we have been worki...
# 3         \r\n<p>1. The structural and ionic requirement...
# 4         \r\n<p>1. The effect of taxol on selected lyso...
# ...                                                     ...
# 10032662  \r\n<p>A hallmark of chronic bacterial infecti...
# 10032663  \r\n<p>Purpose We sought to describe a disorde...
# 10032664  \r\n<p>Background For patients with early Amer...
# 10032665  \r\n<p>Aim of this study The major aim of this...
# 10032666  \r\n<p>Objective To test the impact of inflamm...
#
# [10032667 rows x 3 columns]

# %%
subjects = pd.read_csv('pub_subject_eu.csv')

# drop pubyear 
subjects = subjects.drop(columns=['pubyear'])

# keep rows where ascatype is extended 
subjects = subjects[subjects['ascatype'] == 'extended']
subjects = subjects.drop(columns=['ascatype'])
subjects = subjects.drop_duplicates() 
subjects
# Out:
#                pubid                               subject
# 0             2010.0               Pharmacology & Pharmacy
# 2             2012.0               Pharmacology & Pharmacy
# 4             2013.0               Pharmacology & Pharmacy
# 6             2015.0               Pharmacology & Pharmacy
# 8             2019.0               Pharmacology & Pharmacy
# ...              ...                                   ...
# 32680567  46608410.0                   Genetics & Heredity
# 32680569  46608423.0                           Dermatology
# 32680571  46608429.0  Biotechnology & Applied Microbiology
# 32680572  46608429.0                          Microbiology
# 32680575  46608438.0                          Rheumatology
#
# [15780480 rows x 2 columns]

# %%
df = pd.merge(affauth, publication, on='pubid', how='left')

# group by pubyear and EU_NUTS_ID and count the number of unique pubid
df.groupby(['pubyear', 'EU_NUTS_ID'])['pubid'].nunique().sort_index()
df
# Out:
#                pubid  pubyear EU_NUTS_ID  \
# 0             2010.0     1998      ES415
# 1             2012.0     1998      NL327
# 2             2013.0     1998      ES111
# 3             2015.0     1998      UKJ36
# 4             2019.0     1998      PL331
# ...              ...      ...        ...
# 17571110  46608438.0     2021      FR101
# 17571111  46608438.0     2021      PT170
# 17571112  46608438.0     2021      NL423
# 17571113  46608438.0     2021      NL326
# 17571114  46608438.0     2021      FR431
#
#                                                   itemtitle  \
# 0         Pharmacology of JB-9315, a new selective hista...
# 1         Focal cerebral ischemia in the mouse: Hypother...
# 2         Pyridazine derivatives XIV. Study of the vasor...
# 3         Structural requirements and ionic mechanism of...
# 4         Activity of lysosomal system in mouse liver af...
# ...                                                     ...
# 17571110  Inflammation of the Sacroiliac Joints and Spin...
# 17571111  Inflammation of the Sacroiliac Joints and Spin...
# 17571112  Inflammation of the Sacroiliac Joints and Spin...
# 17571113  Inflammation of the Sacroiliac Joints and Spin...
# 17571114  Inflammation of the Sacroiliac Joints and Spin...
#
#                                                    abstract
# 0         \r\n<p>1. The histamine H-2 receptor antagonis...
# 1         \r\n<p>1. We have investigated the ability of ...
# 2         \r\n<p>1. For several years we have been worki...
# 3         \r\n<p>1. The structural and ionic requirement...
# 4         \r\n<p>1. The effect of taxol on selected lyso...
# ...                                                     ...
# 17571110  \r\n<p>Objective To test the impact of inflamm...
# 17571111  \r\n<p>Objective To test the impact of inflamm...
# 17571112  \r\n<p>Objective To test the impact of inflamm...
# 17571113  \r\n<p>Objective To test the impact of inflamm...
# 17571114  \r\n<p>Objective To test the impact of inflamm...
#
# [17571115 rows x 5 columns]

# %%
# create 'period' column 
def assign_period(pubyear):
    if 1998 <= pubyear <= 2001:
        return 1
    elif 2002 <= pubyear <= 2005:
        return 2
    elif 2006 <= pubyear <= 2009:
        return 3
    elif 2010 <= pubyear <= 2013:
        return 4
    elif 2014 <= pubyear <= 2017:
        return 5
    elif 2018 <= pubyear <= 2021:
        return 6
    else:
        return None

df['period'] = df['pubyear'].apply(assign_period)
df.head()
# Out:
#     pubid  pubyear EU_NUTS_ID  \
# 0  2010.0     1998      ES415
# 1  2012.0     1998      NL327
# 2  2013.0     1998      ES111
# 3  2015.0     1998      UKJ36
# 4  2019.0     1998      PL331
#
#                                            itemtitle  \
# 0  Pharmacology of JB-9315, a new selective hista...
# 1  Focal cerebral ischemia in the mouse: Hypother...
# 2  Pyridazine derivatives XIV. Study of the vasor...
# 3  Structural requirements and ionic mechanism of...
# 4  Activity of lysosomal system in mouse liver af...
#
#                                             abstract  period
# 0  \r\n<p>1. The histamine H-2 receptor antagonis...       1
# 1  \r\n<p>1. We have investigated the ability of ...       1
# 2  \r\n<p>1. For several years we have been worki...       1
# 3  \r\n<p>1. The structural and ionic requirement...       1
# 4  \r\n<p>1. The effect of taxol on selected lyso...       1

# %%
df = pd.merge(df, subjects, on='pubid', how='left')
df
# Out:
#                pubid  pubyear EU_NUTS_ID  \
# 0             2010.0     1998      ES415
# 1             2012.0     1998      NL327
# 2             2013.0     1998      ES111
# 3             2015.0     1998      UKJ36
# 4             2019.0     1998      PL331
# ...              ...      ...        ...
# 27357673  46608438.0     2021      FR101
# 27357674  46608438.0     2021      PT170
# 27357675  46608438.0     2021      NL423
# 27357676  46608438.0     2021      NL326
# 27357677  46608438.0     2021      FR431
#
#                                                   itemtitle  \
# 0         Pharmacology of JB-9315, a new selective hista...
# 1         Focal cerebral ischemia in the mouse: Hypother...
# 2         Pyridazine derivatives XIV. Study of the vasor...
# 3         Structural requirements and ionic mechanism of...
# 4         Activity of lysosomal system in mouse liver af...
# ...                                                     ...
# 27357673  Inflammation of the Sacroiliac Joints and Spin...
# 27357674  Inflammation of the Sacroiliac Joints and Spin...
# 27357675  Inflammation of the Sacroiliac Joints and Spin...
# 27357676  Inflammation of the Sacroiliac Joints and Spin...
# 27357677  Inflammation of the Sacroiliac Joints and Spin...
#
#                                                    abstract  period  \
# 0         \r\n<p>1. The histamine H-2 receptor antagonis...       1
# 1         \r\n<p>1. We have investigated the ability of ...       1
# 2         \r\n<p>1. For several years we have been worki...       1
# 3         \r\n<p>1. The structural and ionic requirement...       1
# 4         \r\n<p>1. The effect of taxol on selected lyso...       1
# ...                                                     ...     ...
# 27357673  \r\n<p>Objective To test the impact of inflamm...       6
# 27357674  \r\n<p>Objective To test the impact of inflamm...       6
# 27357675  \r\n<p>Objective To test the impact of inflamm...       6
# 27357676  \r\n<p>Objective To test the impact of inflamm...       6
# 27357677  \r\n<p>Objective To test the impact of inflamm...       6
#
#                           subject
# 0         Pharmacology & Pharmacy
# 1         Pharmacology & Pharmacy
# 2         Pharmacology & Pharmacy
# 3         Pharmacology & Pharmacy
# 4         Pharmacology & Pharmacy
# ...                           ...
# 27357673             Rheumatology
# 27357674             Rheumatology
# 27357675             Rheumatology
# 27357676             Rheumatology
# 27357677             Rheumatology
#
# [27357678 rows x 7 columns]

# %%
# remove '\r\n<p>' from the abstracts 
df['abstract'] = df['abstract'].str.replace('\r\n<p>', '')
df.head()
# Out:
#     pubid  pubyear EU_NUTS_ID  \
# 0  2010.0     1998      ES415
# 1  2012.0     1998      NL327
# 2  2013.0     1998      ES111
# 3  2015.0     1998      UKJ36
# 4  2019.0     1998      PL331
#
#                                            itemtitle  \
# 0  Pharmacology of JB-9315, a new selective hista...
# 1  Focal cerebral ischemia in the mouse: Hypother...
# 2  Pyridazine derivatives XIV. Study of the vasor...
# 3  Structural requirements and ionic mechanism of...
# 4  Activity of lysosomal system in mouse liver af...
#
#                                             abstract  period  \
# 0  1. The histamine H-2 receptor antagonistic act...       1
# 1  1. We have investigated the ability of several...       1
# 2  1. For several years we have been working on t...       1
# 3  1. The structural and ionic requirements for p...       1
# 4  1. The effect of taxol on selected lysosomal e...       1
#
#                    subject
# 0  Pharmacology & Pharmacy
# 1  Pharmacology & Pharmacy
# 2  Pharmacology & Pharmacy
# 3  Pharmacology & Pharmacy
# 4  Pharmacology & Pharmacy

# %% [markdown]
# **2-1. 외부 협력 논문 제외**

# %%
# Remove rows where pubid are associated with multiple 'EU_NUTS_ID' 
# Find pubids with more than one unique EU_NUTS_ID
pubids_multiple_ids = df.groupby('pubid')['EU_NUTS_ID'].nunique()
pubids_to_remove = pubids_multiple_ids[pubids_multiple_ids > 1].index

# Filter out those pubids from df
df_filtered = df[~df['pubid'].isin(pubids_to_remove)]
df_filtered
# Out:
#                pubid  pubyear EU_NUTS_ID  \
# 0             2010.0     1998      ES415
# 1             2012.0     1998      NL327
# 2             2013.0     1998      ES111
# 3             2015.0     1998      UKJ36
# 4             2019.0     1998      PL331
# ...              ...      ...        ...
# 27357649  46608396.0     2021      HU333
# 27357650  46608396.0     2021      HU333
# 27357661  46608401.0     2021      IE021
# 27357670  46608429.0     2021      PT11A
# 27357671  46608429.0     2021      PT11A
#
#                                                   itemtitle  \
# 0         Pharmacology of JB-9315, a new selective hista...
# 1         Focal cerebral ischemia in the mouse: Hypother...
# 2         Pyridazine derivatives XIV. Study of the vasor...
# 3         Structural requirements and ionic mechanism of...
# 4         Activity of lysosomal system in mouse liver af...
# ...                                                     ...
# 27357649            DNA Methylation in Huntington's Disease
# 27357650            DNA Methylation in Huntington's Disease
# 27357661  A population-level strain genotyping method to...
# 27357670  Karlodinium veneficum: Growth optimization, me...
# 27357671  Karlodinium veneficum: Growth optimization, me...
#
#                                                    abstract  period  \
# 0         1. The histamine H-2 receptor antagonistic act...       1
# 1         1. We have investigated the ability of several...       1
# 2         1. For several years we have been working on t...       1
# 3         1. The structural and ionic requirements for p...       1
# 4         1. The effect of taxol on selected lysosomal e...       1
# ...                                                     ...     ...
# 27357649  Methylation of cytosine in CpG dinucleotides i...       6
# 27357650  Methylation of cytosine in CpG dinucleotides i...       6
# 27357661  A hallmark of chronic bacterial infections is ...       6
# 27357670  Aim of this study The major aim of this work w...       6
# 27357671  Aim of this study The major aim of this work w...       6
#
#                                        subject
# 0                      Pharmacology & Pharmacy
# 1                      Pharmacology & Pharmacy
# 2                      Pharmacology & Pharmacy
# 3                      Pharmacology & Pharmacy
# 4                      Pharmacology & Pharmacy
# ...                                        ...
# 27357649      Biochemistry & Molecular Biology
# 27357650                             Chemistry
# 27357661      Research & Experimental Medicine
# 27357670  Biotechnology & Applied Microbiology
# 27357671                          Microbiology
#
# [9457394 rows x 7 columns]

# %%
# check number of unique pubid 
df_filtered['pubid'].nunique()
# Out:
# 6021654

# %%
# Identify pubids with more than one unique EU_NUTS_ID
pubids_multiple_ids = df.groupby('pubid')['EU_NUTS_ID'].nunique()
pubids_to_keep = pubids_multiple_ids[pubids_multiple_ids > 1].index

# Keep only those pubids
df_external_collab = df[df['pubid'].isin(pubids_to_keep)]
df_external_collab = df_external_collab.drop_duplicates()
df_external_collab
# Out:
#                pubid  pubyear EU_NUTS_ID  \
# 5             3080.0     1998      NL230
# 6             3080.0     1998      NL230
# 7             3080.0     1998      DE80N
# 8             3080.0     1998      DE80N
# 13            3085.0     1998      DE131
# ...              ...      ...        ...
# 27357673  46608438.0     2021      FR101
# 27357674  46608438.0     2021      PT170
# 27357675  46608438.0     2021      NL423
# 27357676  46608438.0     2021      NL326
# 27357677  46608438.0     2021      FR431
#
#                                                   itemtitle  \
# 5         Comparison of DNA application methods to reduc...
# 6         Comparison of DNA application methods to reduc...
# 7         Comparison of DNA application methods to reduc...
# 8         Comparison of DNA application methods to reduc...
# 13        Protection of mice against SV40 tumours by Pam...
# ...                                                     ...
# 27357673  Inflammation of the Sacroiliac Joints and Spin...
# 27357674  Inflammation of the Sacroiliac Joints and Spin...
# 27357675  Inflammation of the Sacroiliac Joints and Spin...
# 27357676  Inflammation of the Sacroiliac Joints and Spin...
# 27357677  Inflammation of the Sacroiliac Joints and Spin...
#
#                                                    abstract  period  \
# 5         We compared the protection afforded by three d...       1
# 6         We compared the protection afforded by three d...       1
# 7         We compared the protection afforded by three d...       1
# 8         We compared the protection afforded by three d...       1
# 13        The intraperitoneal injection of Balb/c mice w...       1
# ...                                                     ...     ...
# 27357673  Objective To test the impact of inflammation o...       6
# 27357674  Objective To test the impact of inflammation o...       6
# 27357675  Objective To test the impact of inflammation o...       6
# 27357676  Objective To test the impact of inflammation o...       6
# 27357677  Objective To test the impact of inflammation o...       6
#
#                                    subject
# 5                               Immunology
# 6         Research & Experimental Medicine
# 7                               Immunology
# 8         Research & Experimental Medicine
# 13                              Immunology
# ...                                    ...
# 27357673                      Rheumatology
# 27357674                      Rheumatology
# 27357675                      Rheumatology
# 27357676                      Rheumatology
# 27357677                      Rheumatology
#
# [17900284 rows x 7 columns]

# %%
df_external_collab.to_csv('1_df_only_external_collab.csv', index=False)

# %%
# check number of unique pubid 
df_external_collab['pubid'].nunique()
# Out:
# 4011013

# %%
# 전체 논문 대비 외부 협력 논문 비율 
total_papers = df['pubid'].nunique()
external_collab_papers = df_external_collab['pubid'].nunique()
external_collab_ratio = external_collab_papers / total_papers
print(f"External collaboration papers ratio: {external_collab_ratio:.4f}")
# Out:
# External collaboration papers ratio: 0.3998

# %% [markdown]
# **2-2. 지역별, 기간별, 분야별 논문 수가 최소 10개 이상인 지역만 포함**

# %%
df = df_filtered.copy()
df
# Out:
#                pubid  pubyear EU_NUTS_ID  \
# 0             2010.0     1998      ES415
# 1             2012.0     1998      NL327
# 2             2013.0     1998      ES111
# 3             2015.0     1998      UKJ36
# 4             2019.0     1998      PL331
# ...              ...      ...        ...
# 27357649  46608396.0     2021      HU333
# 27357650  46608396.0     2021      HU333
# 27357661  46608401.0     2021      IE021
# 27357670  46608429.0     2021      PT11A
# 27357671  46608429.0     2021      PT11A
#
#                                                   itemtitle  \
# 0         Pharmacology of JB-9315, a new selective hista...
# 1         Focal cerebral ischemia in the mouse: Hypother...
# 2         Pyridazine derivatives XIV. Study of the vasor...
# 3         Structural requirements and ionic mechanism of...
# 4         Activity of lysosomal system in mouse liver af...
# ...                                                     ...
# 27357649            DNA Methylation in Huntington's Disease
# 27357650            DNA Methylation in Huntington's Disease
# 27357661  A population-level strain genotyping method to...
# 27357670  Karlodinium veneficum: Growth optimization, me...
# 27357671  Karlodinium veneficum: Growth optimization, me...
#
#                                                    abstract  period  \
# 0         1. The histamine H-2 receptor antagonistic act...       1
# 1         1. We have investigated the ability of several...       1
# 2         1. For several years we have been working on t...       1
# 3         1. The structural and ionic requirements for p...       1
# 4         1. The effect of taxol on selected lysosomal e...       1
# ...                                                     ...     ...
# 27357649  Methylation of cytosine in CpG dinucleotides i...       6
# 27357650  Methylation of cytosine in CpG dinucleotides i...       6
# 27357661  A hallmark of chronic bacterial infections is ...       6
# 27357670  Aim of this study The major aim of this work w...       6
# 27357671  Aim of this study The major aim of this work w...       6
#
#                                        subject
# 0                      Pharmacology & Pharmacy
# 1                      Pharmacology & Pharmacy
# 2                      Pharmacology & Pharmacy
# 3                      Pharmacology & Pharmacy
# 4                      Pharmacology & Pharmacy
# ...                                        ...
# 27357649      Biochemistry & Molecular Biology
# 27357650                             Chemistry
# 27357661      Research & Experimental Medicine
# 27357670  Biotechnology & Applied Microbiology
# 27357671                          Microbiology
#
# [9457394 rows x 7 columns]

# %%
# Step 1: Count number of unique pubid per group
group_counts = df.groupby(['period', 'EU_NUTS_ID', 'subject'])['pubid'].nunique().reset_index(name='count')

# Step 2: Filter to only keep groups with count >= 10
valid_groups = group_counts[group_counts['count'] >= 10][['period', 'EU_NUTS_ID', 'subject']]

# Step 3: Merge with original dataframe to keep only valid rows
df_filtered_2 = df.merge(valid_groups, on=['period', 'EU_NUTS_ID', 'subject'], how='inner')
df_filtered_2
# Out:
#               pubid  pubyear EU_NUTS_ID  \
# 0            2010.0     1998      ES415
# 1            2013.0     1998      ES111
# 2            2015.0     1998      UKJ36
# 3            3081.0     1998      UKI31
# 4            3081.0     1998      UKI31
# ...             ...      ...        ...
# 8733403  46608396.0     2021      HU333
# 8733404  46608396.0     2021      HU333
# 8733405  46608401.0     2021      IE021
# 8733406  46608429.0     2021      PT11A
# 8733407  46608429.0     2021      PT11A
#
#                                                  itemtitle  \
# 0        Pharmacology of JB-9315, a new selective hista...
# 1        Pyridazine derivatives XIV. Study of the vasor...
# 2        Structural requirements and ionic mechanism of...
# 3        Protection against measles virus-induced encep...
# 4        Protection against measles virus-induced encep...
# ...                                                    ...
# 8733403            DNA Methylation in Huntington's Disease
# 8733404            DNA Methylation in Huntington's Disease
# 8733405  A population-level strain genotyping method to...
# 8733406  Karlodinium veneficum: Growth optimization, me...
# 8733407  Karlodinium veneficum: Growth optimization, me...
#
#                                                   abstract  period  \
# 0        1. The histamine H-2 receptor antagonistic act...       1
# 1        1. For several years we have been working on t...       1
# 2        1. The structural and ionic requirements for p...       1
# 3        Balb/c mice were immunized intranasally (i.n.)...       1
# 4        Balb/c mice were immunized intranasally (i.n.)...       1
# ...                                                    ...     ...
# 8733403  Methylation of cytosine in CpG dinucleotides i...       6
# 8733404  Methylation of cytosine in CpG dinucleotides i...       6
# 8733405  A hallmark of chronic bacterial infections is ...       6
# 8733406  Aim of this study The major aim of this work w...       6
# 8733407  Aim of this study The major aim of this work w...       6
#
#                                       subject
# 0                     Pharmacology & Pharmacy
# 1                     Pharmacology & Pharmacy
# 2                     Pharmacology & Pharmacy
# 3                                  Immunology
# 4            Research & Experimental Medicine
# ...                                       ...
# 8733403      Biochemistry & Molecular Biology
# 8733404                             Chemistry
# 8733405      Research & Experimental Medicine
# 8733406  Biotechnology & Applied Microbiology
# 8733407                          Microbiology
#
# [8733408 rows x 7 columns]

# %%
# Optional: check result
print(f"Original rows: {len(df)}")
print(f"Filtered rows: {len(df_filtered_2)}")
# Out:
# Original rows: 9457394
# Filtered rows: 8733408

# %%
# group by pubyear and EU_NUTS_ID and count the number of unique pubid
check = df_filtered_2.groupby(['period', 'EU_NUTS_ID', 'subject'])['pubid'].nunique().sort_index()
check.describe()
# Out:
# count    134931.000000
# mean         64.724993
# std         124.798134
# min          10.000000
# 25%          16.000000
# 50%          28.000000
# 75%          62.000000
# max        3910.000000
# Name: pubid, dtype: float64

# %%
df_filtered_2.to_csv('1_df_excl_external_collab.csv', index=False)
